# %%
import pandas as pd
students=pd.read_csv("StudentPerformanceFactors.csv")
print(students)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                            No            7               73
# 1                            No            8               59
# 2                           Yes            7               91
# 3                           Yes            8               98
# 4                           Yes            6               65
# ...                         ...          ...              ...
# 6602                         No            7               76
# 6603                         No            8               81
# 6604                        Yes            6               65
# 6605                        Yes            6               91
# 6606                        Yes            9               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 0                 Low             Yes                  0           Low
# 1                 Low             Yes                  2        Medium
# 2              Medium             Yes                  2        Medium
# 3              Medium             Yes                  1        Medium
# 4              Medium             Yes                  3        Medium
# ...               ...             ...                ...           ...
# 6602           Medium             Yes                  1          High
# 6603           Medium             Yes                  3           Low
# 6604              Low             Yes                  3           Low
# 6605             High             Yes                  2           Low
# 6606           Medium             Yes                  0        Medium
#
#      Teacher_Quality School_Type Peer_Influence  Physical_Activity  \
# 0             Medium      Public       Positive                  3
# 1             Medium      Public       Negative                  4
# 2             Medium      Public        Neutral                  4
# 3             Medium      Public       Negative                  4
# 4               High      Public        Neutral                  4
# ...              ...         ...            ...                ...
# 6602          Medium      Public       Positive                  2
# 6603            High      Public       Positive                  2
# 6604          Medium      Public       Negative                  2
# 6605          Medium     Private       Positive                  3
# 6606          Medium      Public       Positive                  4
#
#      Learning_Disabilities Parental_Education_Level Distance_from_Home  \
# 0                       No              High School               Near
# 1                       No                  College           Moderate
# 2                       No             Postgraduate               Near
# 3                       No              High School           Moderate
# 4                       No                  College               Near
# ...                    ...                      ...                ...
# 6602                    No              High School               Near
# 6603                    No              High School               Near
# 6604                    No             Postgraduate               Near
# 6605                    No              High School                Far
# 6606                    No             Postgraduate               Near
#
#       Gender  Exam_Score
# 0       Male          67
# 1     Female          61
# 2       Male          74
# 3       Male          71
# 4     Female          70
# ...      ...         ...
# 6602  Female          68
# 6603  Female          69
# 6604  Female          68
# 6605  Female          68
# 6606    Male          64
#
# [6607 rows x 20 columns]

# %%
import pandas as pd
habits=pd.read_csv("student_habits_performance.csv")
print(habits)
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0              1.1            No                   85.0          8.0
# 1              2.3            No                   97.3          4.6
# 2              1.3            No                   94.8          8.0
# 3              1.0            No                   71.0          9.2
# 4              0.5            No                   90.9          4.9
# ..             ...           ...                    ...          ...
# 995            1.6            No                   77.0          7.5
# 996            2.4           Yes                   86.0          6.8
# 997            1.3            No                   61.9          6.5
# 998            1.1           Yes                  100.0          7.6
# 999            1.9            No                   89.4          7.1
#
#     diet_quality  exercise_frequency parental_education_level  \
# 0           Fair                   6                   Master
# 1           Good                   6              High School
# 2           Poor                   1              High School
# 3           Poor                   4                   Master
# 4           Fair                   3                   Master
# ..           ...                 ...                      ...
# 995         Fair                   2              High School
# 996         Poor                   1              High School
# 997         Good                   5                 Bachelor
# 998         Fair                   0                 Bachelor
# 999         Good                   2                 Bachelor
#
#     internet_quality  mental_health_rating extracurricular_participation  \
# 0            Average                     8                           Yes
# 1            Average                     8                            No
# 2               Poor                     1                            No
# 3               Good                     1                           Yes
# 4               Good                     1                            No
# ..               ...                   ...                           ...
# 995             Good                     6                           Yes
# 996          Average                     6                           Yes
# 997             Good                     9                           Yes
# 998          Average                     1                            No
# 999          Average                     8                            No
#
#      exam_score
# 0          56.2
# 1         100.0
# 2          34.3
# 3          26.8
# 4          66.4
# ..          ...
# 995        76.1
# 996        65.9
# 997        64.4
# 998        69.7
# 999        74.9
#
# [1000 rows x 16 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a histogram
plt.hist(habits.exam_score, bins=12, density=True, color='pink', edgecolor='black', label='Data Distribution')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Student Habits Test Scores')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

exam=pd.read_csv("ExamScore.csv")

# Create a histogram
plt.hist(exam, bins=12, density=True, color='pink', edgecolor='black', label='Data Distribution')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Student Performance Factors Test Scores')
plt.legend()
plt.grid(True)
plt.show()

# %%
print(students.Sleep_Hours)
# Out:
# 0       7
# 1       8
# 2       7
# 3       8
# 4       6
#        ..
# 6602    7
# 6603    8
# 6604    6
# 6605    6
# 6606    9
# Name: Sleep_Hours, Length: 6607, dtype: int64

# %%
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

plt.figure(figsize=(6,6))
plt.xlabel('Student ID')
plt.ylabel('Test Score')
plt.title('Student Performance Factors Test Scores')
plt.plot(exam)

# %%
#encode Parental_Involvement column to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_2 = students.Parental_Involvement
set_col_2 = list(set(col_2))
le.fit(col_2)
dict(zip(set_col_2, le.transform(set_col_2)))

students.Parental_Involvement = le.transform(students.Parental_Involvement)

print(students.Parental_Involvement)
# Out:
# 0       1
# 1       1
# 2       2
# 3       1
# 4       2
#        ..
# 6602    0
# 6603    0
# 6604    2
# 6605    0
# 6606    2
# Name: Parental_Involvement, Length: 6607, dtype: int32

# %%
#encode Access_to_Resources column to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_3 = students.Access_to_Resources
set_col_3 = list(set(col_3))
le.fit(col_3)
dict(zip(set_col_3, le.transform(set_col_3)))

students.Access_to_Resources = le.transform(students.Access_to_Resources)

print(students.Access_to_Resources)
# Out:
# 0       0
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 6602    2
# 6603    2
# 6604    1
# 6605    0
# 6606    1
# Name: Access_to_Resources, Length: 6607, dtype: int32

# %%
#encode Extracurricular_Activities column to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_4 = students.Extracurricular_Activities
set_col_4 = list(set(col_4))
le.fit(col_4)
dict(zip(set_col_4, le.transform(set_col_4)))

students.Extracurricular_Activities = le.transform(students.Extracurricular_Activities)

print(students.Extracurricular_Activities)
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       1
#        ..
# 6602    0
# 6603    0
# 6604    1
# 6605    1
# 6606    1
# Name: Extracurricular_Activities, Length: 6607, dtype: int32

# %%
#encode Motivation_Level column to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_7 = students.Motivation_Level
set_col_7 = list(set(col_7))
le.fit(col_7)
dict(zip(set_col_7, le.transform(set_col_7)))

students.Motivation_Level = le.transform(students.Motivation_Level)

print(students.Motivation_Level)
# Out:
# 0       1
# 1       1
# 2       2
# 3       2
# 4       2
#        ..
# 6602    2
# 6603    2
# 6604    1
# 6605    0
# 6606    2
# Name: Motivation_Level, Length: 6607, dtype: int32

# %%
#encode Internet_Access to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_8 = students.Internet_Access
set_col_8 = list(set(col_8))
le.fit(col_8)
dict(zip(set_col_8, le.transform(set_col_8)))

students.Internet_Access = le.transform(students.Internet_Access)

print(students.Internet_Access)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6602    1
# 6603    1
# 6604    1
# 6605    1
# 6606    1
# Name: Internet_Access, Length: 6607, dtype: int32

# %%
#encode Family_Income to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_10 = students.Family_Income
set_col_10 = list(set(col_10))
le.fit(col_10)
dict(zip(set_col_10, le.transform(set_col_10)))

students.Family_Income = le.transform(students.Family_Income)

print(students.Family_Income)
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 6602    0
# 6603    1
# 6604    1
# 6605    1
# 6606    2
# Name: Family_Income, Length: 6607, dtype: int32

# %%
#encode Teacher_Quality to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_11 = students.Teacher_Quality
set_col_11 = list(set(col_11))
le.fit(col_11)
dict(zip(set_col_11, le.transform(set_col_11)))

students.Teacher_Quality = le.transform(students.Teacher_Quality)

print(students.Teacher_Quality)
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       0
#        ..
# 6602    2
# 6603    0
# 6604    2
# 6605    2
# 6606    2
# Name: Teacher_Quality, Length: 6607, dtype: int32

# %%
#encode School_Type to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_12 = students.School_Type
set_col_12 = list(set(col_12))
le.fit(col_12)
dict(zip(set_col_12, le.transform(set_col_12)))

students.School_Type = le.transform(students.School_Type)

print(students.School_Type)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6602    1
# 6603    1
# 6604    1
# 6605    0
# 6606    1
# Name: School_Type, Length: 6607, dtype: int32

# %%
#encode Peer_Influence to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_13 = students.Peer_Influence
set_col_13 = list(set(col_13))
le.fit(col_13)
dict(zip(set_col_13, le.transform(set_col_13)))

students.Peer_Influence = le.transform(students.Peer_Influence)

print(students.Peer_Influence)
# Out:
# 0       2
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 6602    2
# 6603    2
# 6604    0
# 6605    2
# 6606    2
# Name: Peer_Influence, Length: 6607, dtype: int32

# %%
#encode Learning_Disabilities to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_15 = students.Learning_Disabilities
set_col_15 = list(set(col_15))
le.fit(col_15)
dict(zip(set_col_15, le.transform(set_col_15)))

students.Learning_Disabilities = le.transform(students.Learning_Disabilities)

print(students.Learning_Disabilities)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6602    0
# 6603    0
# 6604    0
# 6605    0
# 6606    0
# Name: Learning_Disabilities, Length: 6607, dtype: int32

# %%
#encode Parental_Education_Level to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_16 = students.Parental_Education_Level
set_col_16 = list(set(col_16))
le.fit(col_16)
dict(zip(set_col_16, le.transform(set_col_16)))

students.Parental_Education_Level = le.transform(students.Parental_Education_Level)

print(students.Parental_Education_Level)
# Out:
# 0       1
# 1       0
# 2       2
# 3       1
# 4       0
#        ..
# 6602    1
# 6603    1
# 6604    2
# 6605    1
# 6606    2
# Name: Parental_Education_Level, Length: 6607, dtype: int32

# %%
#encode Distance_from_Home to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_17 = students.Distance_from_Home
set_col_17 = list(set(col_17))
le.fit(col_17)
dict(zip(set_col_17, le.transform(set_col_17)))

students.Distance_from_Home = le.transform(students.Distance_from_Home)

print(students.Distance_from_Home)
# Out:
# 0       2
# 1       1
# 2       2
# 3       1
# 4       2
#        ..
# 6602    2
# 6603    2
# 6604    2
# 6605    0
# 6606    2
# Name: Distance_from_Home, Length: 6607, dtype: int32

# %%
#encode Gender to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_18 = students.Gender
set_col_18 = list(set(col_18))
le.fit(col_18)
dict(zip(set_col_18, le.transform(set_col_18)))

students.Gender = le.transform(students.Gender)

print(students.Gender)
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 6602    0
# 6603    0
# 6604    0
# 6605    0
# 6606    1
# Name: Gender, Length: 6607, dtype: int32

# %%
exam_score=pd.read_csv("ExamScore.csv")
print(exam_score)
# Out:
#       Exam_Score
# 0             67
# 1             61
# 2             74
# 3             71
# 4             70
# ...          ...
# 6602          68
# 6603          69
# 6604          68
# 6605          68
# 6606          64
#
# [6607 rows x 1 columns]

# %%
#convert 2-D array to 1-D
scoreresult = []

for i in range(0, len(exam_score.Exam_Score)):
# %%
# Initializing empty lists to append all model's name and corresponding name
acc = []
aec = []
model = []

# %%
#Use a DecisionTreeClassifier machine algorithm with looping max_depth parameter

from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn import tree

from sklearn.tree import DecisionTreeClassifier

results = []
random_state = []
max_depth = []

for i in range(2, 20):
    for j in range(2, 20):
        DecisionTree = DecisionTreeClassifier(criterion="entropy",random_state=j,max_depth=i)
        DecisionTree.fit(X_train, y_train)
        predicted_values = DecisionTree.predict(X_test)
        x = metrics.accuracy_score(y_test, predicted_values)
        max_depth.append(x*100)
    results.append(max_depth)
    max_depth = []

import matplotlib.pyplot as plt

plt.plot(results, alpha=0.5)
# Out:
# [<matplotlib.lines.Line2D at 0x16af9b6ecf0>,
#  <matplotlib.lines.Line2D at 0x16af9b276e0>,
#  <matplotlib.lines.Line2D at 0x16af9b6ee40>,
#  <matplotlib.lines.Line2D at 0x16af9b6ef30>,
#  <matplotlib.lines.Line2D at 0x16affd127e0>,
#  <matplotlib.lines.Line2D at 0x16af9b6f0b0>,
#  <matplotlib.lines.Line2D at 0x16af9b6f1a0>,
#  <matplotlib.lines.Line2D at 0x16af9b6f290>,
#  <matplotlib.lines.Line2D at 0x16af9b6f380>,
#  <matplotlib.lines.Line2D at 0x16af9b6dc10>,
#  <matplotlib.lines.Line2D at 0x16af9b6f440>,
#  <matplotlib.lines.Line2D at 0x16af9b6f530>,
#  <matplotlib.lines.Line2D at 0x16affdc8920>,
#  <matplotlib.lines.Line2D at 0x16af9b6f6e0>,
#  <matplotlib.lines.Line2D at 0x16af9b6f7d0>,
#  <matplotlib.lines.Line2D at 0x16afe8c7aa0>,
#  <matplotlib.lines.Line2D at 0x16af9b6f950>,
#  <matplotlib.lines.Line2D at 0x16af9b6fa40>]

# %%
#Use a RandomForestClassifier machine algorithm with looping n_estimators parameter

from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
import warnings

warnings.filterwarnings('ignore')

results = []
results2 = []
random_state = []

import numpy as np

# Convert exam scores to letter grades
def score_to_grade(score):
    if isinstance(score, str) and score in ['A', 'B', 'C', 'D', 'F']:
        return score  # already a letter grade
    score = float(score)
    if score >= 90:
        return 'A'
    elif score >= 80:
        return 'B'
    elif score >= 70:
        return 'C'
    elif score >= 60:
        return 'D'
    else:
        return 'F'

# Apply the conversion to labels
y_train = np.array([score_to_grade(s) for s in y_train])
y_test = np.array([score_to_grade(s) for s in y_test])

for i in range(2, 20):
    random_state.append(i)
    clf = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='sqrt', max_leaf_nodes=None,
            min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.0,
            n_estimators=i, n_jobs=-1, oob_score=False, random_state=42,
            verbose=0, warm_start=False)
    clf.fit(X_train, y_train)
    predicted_values = clf.predict(X_test)
    x = metrics.accuracy_score(y_test, predicted_values)
    results.append(x)
    
    #i=0
    diff = []
    diff_tot = 0

    for i, score in enumerate(y_test):
        is_wrong = int(predicted_values[i] != score)  # 1 if incorrect, 0 if correct
        diff.append(is_wrong)
        diff_tot += is_wrong

    rfc_avg = diff_tot / len(predicted_values)  # classification error rate
    results2.append(rfc_avg)

import matplotlib.pyplot as plt 

plt.scatter(random_state, results2, s=10, c='r', alpha=0.5)
print(results)
# Out:
# [0.972768532526475, 0.9914271306101866, 0.989409984871407, 0.994452849218356, 0.9929399899142713, 0.9924357034795764, 0.9914271306101866, 0.9914271306101866, 0.9934442763489663, 0.9929399899142713, 0.9934442763489663, 0.9929399899142713, 0.9934442763489663, 0.9924357034795764, 0.9919314170448815, 0.9929399899142713, 0.9914271306101866, 0.9929399899142713]

# %%
#useful tutorial at: https://www.geeksforgeeks.org/random-forest-classifier-using-scikit-learn/

from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()

# %%
RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='auto', max_leaf_nodes=None,
            min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0,
            n_estimators=15, n_jobs=1, oob_score=False, random_state=None,
            verbose=0, warm_start=False)
# Out:
# RandomForestClassifier(max_features='auto', n_estimators=15, n_jobs=1)

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# make predictions
y_predict = clf.predict(X_test)

x = metrics.accuracy_score(y_test, predicted_values)
acc.append(x)
model.append('Random Forest')
print("Random Forest's Accuracy is: ", x)

print(classification_report(y_test, predicted_values))
# Out:
# Random Forest's Accuracy is:  0.9929399899142713
#               precision    recall  f1-score   support
#
#            A       0.00      0.00      0.00         5
#            B       1.00      0.33      0.50         9
#            C       0.98      1.00      0.99       451
#            D       1.00      1.00      1.00      1494
#            F       1.00      0.88      0.93        24
#
#     accuracy                           0.99      1983
#    macro avg       0.79      0.64      0.68      1983
# weighted avg       0.99      0.99      0.99      1983

# %%
# show the inputs and predicted outputs and make an array of differences
i=0
diff = []
diff_tot = 0

for score in y_test:
    #diff.append([y_predict[i], score])
    #print("n=%s, Predicted=%s, Actual=%s" % (i, y_predict[i], score))
    if (y_predict[i]==score):
        diff_tot = diff_tot + 0
        diff.append(0)
    elif (y_predict[i]=='A' and score=='B') or (y_predict[i]=='B' and score=='C') or (y_predict[i]=='C' and score=='D') or (y_predict[i]=='D' and score=='F') or (score=='A' and y_predict[i]=='B') or (score=='B' and y_predict[i]=='C') or (score=='C' and y_predict[i]=='D') or (score=='D' and y_predict[i]=='F'):
        diff_tot = diff_tot + 1
        diff.append(1)
    elif (y_predict[i]=='A' and score=='C') or (y_predict[i]=='B' and score=='D') or (y_predict[i]=='C' and score=='F') or (score=='A' and y_predict[i]=='C') or (score=='B' and y_predict[i]=='D') or (score=='C' and y_predict[i]=='F'):
        diff_tot = diff_tot + 2
        diff.append(3)
    elif (y_predict[i]=='A' and score=='D') or (y_predict[i]=='B' and score=='F') or (score=='A' and y_predict[i]=='D') or (score=='B' and y_predict[i]=='F'):
        diff_tot = diff_tot + 3
        diff.append(3)
    else:
        diff_tot = diff_tot + 4
        diff.append(4)
    i=i+1
    
rfc_avg = diff_tot/len(y_predict)
aec.append(rfc_avg)

print("Average error in score: ", diff_tot/len(y_predict))
# Out:
# Average error in score:  0.007564296520423601

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a histogram
plt.hist(diff, bins=5, density=True, color='skyblue', edgecolor='black', label='Data Distribution')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Prediction Error')
plt.legend()
plt.grid(True)
plt.show()

# %%
#show an exact accuracy comparison

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=[10,5],dpi = 100)
plt.title('Accuracy Comparison Predicting Exact Score (longer is better)')
plt.xlabel('Accuracy')
plt.ylabel('Algorithm')
sns.barplot(x = acc,y = model,palette='dark')
# Out:
# <Axes: title={'center': 'Accuracy Comparison Predicting Exact Score (longer is better)'}, xlabel='Accuracy', ylabel='Algorithm'>

# %%
#show an amount of average error comparison

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=[10,5],dpi = 100)
plt.title('Accuracy Comparison Average Score Error (shorter is better)')
plt.xlabel('Accuracy')
plt.ylabel('Algorithm')
sns.barplot(x = aec,y = model,palette='dark')
# Out:
# <Axes: title={'center': 'Accuracy Comparison Average Score Error (shorter is better)'}, xlabel='Accuracy', ylabel='Algorithm'>

# %%
#Make a Random Forest prediction on a new case

import numpy as np

data = np.array([[10,78,1,2,1,8,74,2,1,1,0,2,0,1,4,0,2,0,0]])
prediction = clf.predict(data)
print(prediction)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 6
#       3 import numpy as np
#       5 data = np.array([[10,78,1,2,1,8,74,2,1,1,0,2,0,1,4,0,2,0,0]])
# ----> 6 prediction = clf.predict(data)
#       7 print(prediction)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:904, in ForestClassifier.predict(self, X)
#     883 def predict(self, X):
#     884     """
#     885     Predict class for X.
#     886
#    (...)
#     902         The predicted classes.
#     903     """
# --> 904     proba = self.predict_proba(X)
#     906     if self.n_outputs_ == 1:
#     907         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:946, in ForestClassifier.predict_proba(self, X)
#     944 check_is_fitted(self)
#     945 # Check data
# --> 946 X = self._validate_X_predict(X)
#     948 # Assign chunk of trees to jobs
#     949 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:641, in BaseForest._validate_X_predict(self, X)
#     638 else:
#     639     force_all_finite = True
# --> 641 X = self._validate_data(
#     642     X,
#     643     dtype=DTYPE,
#     644     accept_sparse="csr",
#     645     reset=False,
#     646     force_all_finite=force_all_finite,
#     647 )
#     648 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     649     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 19 features, but RandomForestClassifier is expecting 20 features as input.

# %% [markdown]
# Can we predict Social Media Hours?
#
# 1. Join with data set of student habits to get social media use
# 2. Create new model with social media hours predicted

# %%
print(habits.social_media_hours[5])
# Out:
# 1.3

# %%
print(habits.exam_score[15])
# Out:
# 74.0

# %%
print(exam.Exam_Score[6])
# Out:
# 67

# %%
import pandas as pd
from sklearn.model_selection import train_test_split


# Create a mapping dict from habits.exam_score to social_media_minutes
mapping = dict(zip(habits.exam_score.astype(int), habits.social_media_hours * 60))

social_media_minutes = []

for score in exam.Exam_Score:
    if score >= 100:
        social_media_minutes.append(1.0)  
    else:
        # Use mapping if available, else 0
        social_media_minutes.append(mapping.get(int(score), 0))

# Confirm lengths match your features DataFrame (students)
assert len(social_media_minutes) == len(students), "Length mismatch between features and target!"

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    students, social_media_minutes, test_size=0.3, random_state=42
)

print(f"Training set shape: {X_train.shape}")
print(f"Test set shape: {X_test.shape}")
# Out:
# Training set shape: (4624, 20)
# Test set shape: (1983, 20)

# %%
from sklearn.ensemble import RandomForestClassifier
import warnings

warnings.filterwarnings('ignore')

results = []
results2 = []
random_state = []

import numpy as np

y_train = np.array(y_train).astype(int)
y_test = np.array(y_test).astype(int)

for i in range(2, 60):
    random_state.append(i)
    clf = RandomForestClassifier(bootstrap=True,
            max_depth=20, max_features='sqrt', max_leaf_nodes=None,
            min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0,
            n_estimators=i, n_jobs=-1, oob_score=False, random_state=42,
            verbose=0, warm_start=False)
    clf.fit(X_train, y_train)
    predicted_values = clf.predict(X_test)
    x = clf.score(X_test, y_test)  # classification accuracy
    results.append(x)
    
    diff = []
    diff_tot = 0

    for i, minutes in enumerate(y_test):
        diff_tot += int(predicted_values[i] != y_test[i])  # misclassification count

    rfc_avg = diff_tot / len(predicted_values)  # classification error rate
    results2.append(rfc_avg)

import matplotlib.pyplot as plt 

plt.scatter(random_state, results2, s=10, c='r', alpha=0.5)
plt.xlabel('Number of Trees (n_estimators)')
plt.ylabel('Classification Error Rate')
plt.title('Error Rate vs Number of Trees in Random Forest')
plt.show()
print(results)
# Out:
# [0.5552193645990923, 0.6399394856278366, 0.7130610186585981, 0.7599596570852244, 0.7801311144730206, 0.7881996974281392, 0.7987897125567323, 0.815935451336359, 0.832576903681291, 0.8381240544629349, 0.843166918809884, 0.8472012102874432, 0.8587997982854261, 0.8653555219364599, 0.8613212304589006, 0.8638426626323752, 0.8734241048915784, 0.8724155320221886, 0.8819969742813918, 0.8956127080181543, 0.8966212808875441, 0.8996469994957136, 0.8986384266263238, 0.9041855774079677, 0.9056984367120524, 0.9056984367120524, 0.9107413010590015, 0.9147755925365607, 0.9132627332324761, 0.9157841654059505, 0.9203227433182047, 0.9208270297528997, 0.9203227433182047, 0.9208270297528997, 0.9238527483610691, 0.9248613212304589, 0.9273827534039334, 0.9288956127080181, 0.9314170448814927, 0.929904185577408, 0.9288956127080181, 0.9309127584467978, 0.9319213313161876, 0.929399899142713, 0.9283913262733232, 0.9309127584467978, 0.9319213313161876, 0.9314170448814927, 0.9304084720121029, 0.9324256177508825, 0.929904185577408, 0.9314170448814927, 0.9319213313161876, 0.9314170448814927, 0.9304084720121029, 0.9273827534039334, 0.9288956127080181, 0.9309127584467978]

# %% [markdown]
# Example of another student's tkinter use to create an interactive window

# %%
# Provide ability to add forest or remove forest from the starting point 
# and capture the keyboard and mouse use of the user

from tkinter import *
from tkinter.filedialog import *
from PIL import Image, ImageTk
import numpy as np

# --- functions ---

w = 6 # change brush size
a = 0 # index for color
paints_list=[]
color_list = ["white", "green"]

def change_color():
    global a
    a = (a + 1) % 2  
    
def savefile():
    # Download Ghostscript: https://www.ghostscript.com/releases/gsdnld.html
    # add GhostScript to Path
    canvas.postscript(file="UserForest.eps")
    img = Image.open("UserForest.eps")
    img.save("UserForest.png", lossless=True)

def clear_all():
    """clearing all user inputs"""
    for i in range(len(paints_list)):
        canvas.delete(paints_list[i])
        
    with open("UserRecord.txt", 'w+') as f:
        f.truncate(0)
        
def on_click(event):
    global lastx, lasty
    lastx,  lasty =  event.x, event.y
    
    with open("UserRecord.txt", "a") as f:
        f.write('Cursor clicked at {0}'.format((lastx, lasty)) + "\n")

def on_release(event):
    global lastx, lasty
    lastx,  lasty =  event.x, event.y
    
    with open("UserRecord.txt", "a") as f:
        f.write('Cursor released at {0}'.format((lastx, lasty)) + "\n")
    
def draw(event):
    """
    drawing
    updating the coordinates of the cursor
    adding all the marks created to a list
    """
    global lastx, lasty, c1
    c1 = canvas.create_line((lastx, lasty, event.x, event.y), fill=color_list[a], width = w)
    paints_list.append(c1)
    lastx, lasty = event.x, event.y
    with open("UserRecord.txt", "a") as f:
        f.write('Cursor moved to {0}, brush_size = {1}, color = {2}'.format((lastx, lasty), w, color_list[a]) + "\n")
    
def brush_size(event):
    """changes the width of the line created"""
    global w
    if event.delta > 0:
    # if mouse scrolls up
        w = w + 1
    elif w > 0:
    # if mouse scrolls down
        w = w - 1    

# --- main ---

with open("UserRecord.txt", 'w+') as f:
    f.truncate(0)

app = Tk()
app.geometry("1200x500")
app.title("add/remove forest by painting")

canvas = Canvas(app, width=1200, height=450, bg='white')
canvas.pack(anchor='nw', fill='both', expand=True)

canvas.bind(sequence="<Button-1>", func=on_click, add="+")
canvas.bind(sequence="<ButtonRelease>", func=on_release, add="+")
canvas.bind(sequence="<B1-Motion>", func=draw)
canvas.bind(sequence='<MouseWheel>',func=brush_size)

button = Button(app, text="Save As", command=savefile, height=10, width=20)
button.pack(side=RIGHT)
button1 = Button(app, text="Clear All", command=clear_all, height=10, width=20)
button1.pack(side=RIGHT)
button2 = Button(app, text="Change Color", command=change_color, height=10, width=20)
button2.pack(side=RIGHT)

image = Image.open('forested.png')
image = ImageTk.PhotoImage(image)

canvas.create_image(0, 0, anchor='nw', image=image)

app.mainloop()

# %%
import tkinter as tk

def show_text():
    user_input = entry.get()
    label.config(text=user_input)

root = tk.Tk()
root.title("Simple Input App")

entry = tk.Entry(root)
entry.pack(pady=10)

button = tk.Button(root, text="Show Text", command=show_text)
button.pack(pady=5)

label = tk.Label(root, text="Your text will appear here.")
label.pack(pady=10)

root.mainloop()
