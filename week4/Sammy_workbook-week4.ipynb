# %%
import pandas as pd
students=pd.read_csv("StudentPerformanceFactors.csv")
print(students)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                            No            7               73
# 1                            No            8               59
# 2                           Yes            7               91
# 3                           Yes            8               98
# 4                           Yes            6               65
# ...                         ...          ...              ...
# 6602                         No            7               76
# 6603                         No            8               81
# 6604                        Yes            6               65
# 6605                        Yes            6               91
# 6606                        Yes            9               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 0                 Low             Yes                  0           Low
# 1                 Low             Yes                  2        Medium
# 2              Medium             Yes                  2        Medium
# 3              Medium             Yes                  1        Medium
# 4              Medium             Yes                  3        Medium
# ...               ...             ...                ...           ...
# 6602           Medium             Yes                  1          High
# 6603           Medium             Yes                  3           Low
# 6604              Low             Yes                  3           Low
# 6605             High             Yes                  2           Low
# 6606           Medium             Yes                  0        Medium
#
#      Teacher_Quality School_Type Peer_Influence  Physical_Activity  \
# 0             Medium      Public       Positive                  3
# 1             Medium      Public       Negative                  4
# 2             Medium      Public        Neutral                  4
# 3             Medium      Public       Negative                  4
# 4               High      Public        Neutral                  4
# ...              ...         ...            ...                ...
# 6602          Medium      Public       Positive                  2
# 6603            High      Public       Positive                  2
# 6604          Medium      Public       Negative                  2
# 6605          Medium     Private       Positive                  3
# 6606          Medium      Public       Positive                  4
#
#      Learning_Disabilities Parental_Education_Level Distance_from_Home  Gender
# 0                       No              High School               Near    Male
# 1                       No                  College           Moderate  Female
# 2                       No             Postgraduate               Near    Male
# 3                       No              High School           Moderate    Male
# 4                       No                  College               Near  Female
# ...                    ...                      ...                ...     ...
# 6602                    No              High School               Near  Female
# 6603                    No              High School               Near  Female
# 6604                    No             Postgraduate               Near  Female
# 6605                    No              High School                Far  Female
# 6606                    No             Postgraduate               Near    Male
#
# [6607 rows x 19 columns]

# %%
import pandas as pd
habits=pd.read_csv("student_habits_performance.csv")
print(habits)
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0              1.1            No                   85.0          8.0
# 1              2.3            No                   97.3          4.6
# 2              1.3            No                   94.8          8.0
# 3              1.0            No                   71.0          9.2
# 4              0.5            No                   90.9          4.9
# ..             ...           ...                    ...          ...
# 995            1.6            No                   77.0          7.5
# 996            2.4           Yes                   86.0          6.8
# 997            1.3            No                   61.9          6.5
# 998            1.1           Yes                  100.0          7.6
# 999            1.9            No                   89.4          7.1
#
#     diet_quality  exercise_frequency parental_education_level  \
# 0           Fair                   6                   Master
# 1           Good                   6              High School
# 2           Poor                   1              High School
# 3           Poor                   4                   Master
# 4           Fair                   3                   Master
# ..           ...                 ...                      ...
# 995         Fair                   2              High School
# 996         Poor                   1              High School
# 997         Good                   5                 Bachelor
# 998         Fair                   0                 Bachelor
# 999         Good                   2                 Bachelor
#
#     internet_quality  mental_health_rating extracurricular_participation  \
# 0            Average                     8                           Yes
# 1            Average                     8                            No
# 2               Poor                     1                            No
# 3               Good                     1                           Yes
# 4               Good                     1                            No
# ..               ...                   ...                           ...
# 995             Good                     6                           Yes
# 996          Average                     6                           Yes
# 997             Good                     9                           Yes
# 998          Average                     1                            No
# 999          Average                     8                            No
#
#      exam_score
# 0          56.2
# 1         100.0
# 2          34.3
# 3          26.8
# 4          66.4
# ..          ...
# 995        76.1
# 996        65.9
# 997        64.4
# 998        69.7
# 999        74.9
#
# [1000 rows x 16 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a histogram
plt.hist(habits.exam_score, bins=12, density=True, color='pink', edgecolor='black', label='Data Distribution')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Prediction Error')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

exam=pd.read_csv("exam_score.csv")

# Create a histogram
plt.hist(exam, bins=12, density=True, color='pink', edgecolor='black', label='Data Distribution')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Prediction Error')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[78], line 4
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 4 exam=pd.read_csv("exam_score.csv")
#       6 # Create a histogram
#       7 plt.hist(exam, bins=12, density=True, color='pink', edgecolor='black', label='Data Distribution')
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'exam_score.csv'

# %%
print(students.Sleep_Hours)
# Out:
# 0       7
# 1       8
# 2       7
# 3       8
# 4       6
#        ..
# 6602    7
# 6603    8
# 6604    6
# 6605    6
# 6606    9
# Name: Sleep_Hours, Length: 6607, dtype: int64

# %%
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

plt.figure(figsize=(6,6))
plt.plot(students.Exam_Score)

# %%
#encode Parental_Involvement column to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_2 = students.Parental_Involvement
set_col_2 = list(set(col_2))
le.fit(col_2)
dict(zip(set_col_2, le.transform(set_col_2)))

students.Parental_Involvement = le.transform(students.Parental_Involvement)

print(students.Parental_Involvement)
# Out:
# 0       1
# 1       1
# 2       2
# 3       1
# 4       2
#        ..
# 6602    0
# 6603    0
# 6604    2
# 6605    0
# 6606    2
# Name: Parental_Involvement, Length: 6607, dtype: int64

# %%
#encode Access_to_Resources column to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_3 = students.Access_to_Resources
set_col_3 = list(set(col_3))
le.fit(col_3)
dict(zip(set_col_3, le.transform(set_col_3)))

students.Access_to_Resources = le.transform(students.Access_to_Resources)

print(students.Access_to_Resources)
# Out:
# 0       0
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 6602    2
# 6603    2
# 6604    1
# 6605    0
# 6606    1
# Name: Access_to_Resources, Length: 6607, dtype: int64

# %%
#encode Extracurricular_Activities column to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_4 = students.Extracurricular_Activities
set_col_4 = list(set(col_4))
le.fit(col_4)
dict(zip(set_col_4, le.transform(set_col_4)))

students.Extracurricular_Activities = le.transform(students.Extracurricular_Activities)

print(students.Extracurricular_Activities)
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       1
#        ..
# 6602    0
# 6603    0
# 6604    1
# 6605    1
# 6606    1
# Name: Extracurricular_Activities, Length: 6607, dtype: int64

# %%
#encode Motivation_Level column to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_7 = students.Motivation_Level
set_col_7 = list(set(col_7))
le.fit(col_7)
dict(zip(set_col_7, le.transform(set_col_7)))

students.Motivation_Level = le.transform(students.Motivation_Level)

print(students.Motivation_Level)
# Out:
# 0       1
# 1       1
# 2       2
# 3       2
# 4       2
#        ..
# 6602    2
# 6603    2
# 6604    1
# 6605    0
# 6606    2
# Name: Motivation_Level, Length: 6607, dtype: int64

# %%
#encode Internet_Access to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_8 = students.Internet_Access
set_col_8 = list(set(col_8))
le.fit(col_8)
dict(zip(set_col_8, le.transform(set_col_8)))

students.Internet_Access = le.transform(students.Internet_Access)

print(students.Internet_Access)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6602    1
# 6603    1
# 6604    1
# 6605    1
# 6606    1
# Name: Internet_Access, Length: 6607, dtype: int64

# %%
#encode Family_Income to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_10 = students.Family_Income
set_col_10 = list(set(col_10))
le.fit(col_10)
dict(zip(set_col_10, le.transform(set_col_10)))

students.Family_Income = le.transform(students.Family_Income)

print(students.Family_Income)
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 6602    0
# 6603    1
# 6604    1
# 6605    1
# 6606    2
# Name: Family_Income, Length: 6607, dtype: int64

# %%
#encode Teacher_Quality to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_11 = students.Teacher_Quality
set_col_11 = list(set(col_11))
le.fit(col_11)
dict(zip(set_col_11, le.transform(set_col_11)))

students.Teacher_Quality = le.transform(students.Teacher_Quality)

print(students.Teacher_Quality)
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       0
#        ..
# 6602    2
# 6603    0
# 6604    2
# 6605    2
# 6606    2
# Name: Teacher_Quality, Length: 6607, dtype: int64

# %%
#encode School_Type to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_12 = students.School_Type
set_col_12 = list(set(col_12))
le.fit(col_12)
dict(zip(set_col_12, le.transform(set_col_12)))

students.School_Type = le.transform(students.School_Type)

print(students.School_Type)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6602    1
# 6603    1
# 6604    1
# 6605    0
# 6606    1
# Name: School_Type, Length: 6607, dtype: int64

# %%
#encode Peer_Influence to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_13 = students.Peer_Influence
set_col_13 = list(set(col_13))
le.fit(col_13)
dict(zip(set_col_13, le.transform(set_col_13)))

students.Peer_Influence = le.transform(students.Peer_Influence)

print(students.Peer_Influence)
# Out:
# 0       2
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 6602    2
# 6603    2
# 6604    0
# 6605    2
# 6606    2
# Name: Peer_Influence, Length: 6607, dtype: int64

# %%
#encode Learning_Disabilities to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_15 = students.Learning_Disabilities
set_col_15 = list(set(col_15))
le.fit(col_15)
dict(zip(set_col_15, le.transform(set_col_15)))

students.Learning_Disabilities = le.transform(students.Learning_Disabilities)

print(students.Learning_Disabilities)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6602    0
# 6603    0
# 6604    0
# 6605    0
# 6606    0
# Name: Learning_Disabilities, Length: 6607, dtype: int64

# %%
#encode Parental_Education_Level to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_16 = students.Parental_Education_Level
set_col_16 = list(set(col_16))
le.fit(col_16)
dict(zip(set_col_16, le.transform(set_col_16)))

students.Parental_Education_Level = le.transform(students.Parental_Education_Level)

print(students.Parental_Education_Level)
# Out:
# 0       1
# 1       0
# 2       2
# 3       1
# 4       0
#        ..
# 6602    1
# 6603    1
# 6604    2
# 6605    1
# 6606    2
# Name: Parental_Education_Level, Length: 6607, dtype: int64

# %%
#encode Distance_from_Home to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_17 = students.Distance_from_Home
set_col_17 = list(set(col_17))
le.fit(col_17)
dict(zip(set_col_17, le.transform(set_col_17)))

students.Distance_from_Home = le.transform(students.Distance_from_Home)

print(students.Distance_from_Home)
# Out:
# 0       2
# 1       1
# 2       2
# 3       1
# 4       2
#        ..
# 6602    2
# 6603    2
# 6604    2
# 6605    0
# 6606    2
# Name: Distance_from_Home, Length: 6607, dtype: int64

# %%
#encode Gender to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_18 = students.Gender
set_col_18 = list(set(col_18))
le.fit(col_18)
dict(zip(set_col_18, le.transform(set_col_18)))

students.Gender = le.transform(students.Gender)

print(students.Gender)
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 6602    0
# 6603    0
# 6604    0
# 6605    0
# 6606    1
# Name: Gender, Length: 6607, dtype: int64

# %%
exam_score=pd.read_csv("ExamScore.csv")
print(exam_score)
# Out:
#       Exam_Score
# 0             67
# 1             61
# 2             74
# 3             71
# 4             70
# ...          ...
# 6602          68
# 6603          69
# 6604          68
# 6605          68
# 6606          64
#
# [6607 rows x 1 columns]

# %%
#convert 2-D array to 1-D
scoreresult = []

for i in range(0, len(exam_score.Exam_Score)):
,
#  <matplotlib.lines.Line2D at 0x7fc1afee3af0>,
#  <matplotlib.lines.Line2D at 0x7fc1afee3be0>,
#  <matplotlib.lines.Line2D at 0x7fc1afee1030>,
#  <matplotlib.lines.Line2D at 0x7fc1afee3ca0>,
#  <matplotlib.lines.Line2D at 0x7fc1afee3d90>,
#  <matplotlib.lines.Line2D at 0x7fc1afee3e80>]

# %%
#Use a DecisionTreeClassifier machine algorithm

# https://medium.com/swlh/decision-tree-classification-de64fc4d5aac

from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn import tree

from sklearn.tree import DecisionTreeClassifier

DecisionTree = DecisionTreeClassifier(criterion="entropy",random_state=2,max_depth=5)

DecisionTree.fit(X_train, y_train)

predicted_values = DecisionTree.predict(X_test)
x = metrics.accuracy_score(y_test, predicted_values)

acc.append(x)
model.append('Decision Tree')

print("DecisionTrees's Accuracy is: ", x*100)

print(classification_report(y_test, predicted_values))
# Out:
# DecisionTrees's Accuracy is:  19.667170953101362
#               precision    recall  f1-score   support
#
#           58       0.00      0.00      0.00         5
#           59       0.00      0.00      0.00        13
#           60       0.00      0.00      0.00        25
#           61       0.14      0.12      0.13        59
#           62       0.18      0.14      0.16        78
#           63       0.18      0.15      0.16       109
#           64       0.16      0.16      0.16       161
#           65       0.18      0.34      0.23       192
#           66       0.20      0.14      0.16       227
#           67       0.20      0.27      0.23       202
#           68       0.23      0.30      0.26       232
#           69       0.18      0.11      0.14       195
#           70       0.24      0.33      0.28       149
#           71       0.28      0.10      0.15       128
#           72       0.16      0.10      0.12        98
#           73       0.14      0.10      0.12        49
#           74       0.17      0.30      0.22        27
#           75       0.33      0.31      0.32        16
#           76       0.00      0.00      0.00         4
#           77       0.00      0.00      0.00         2
#           78       0.00      0.00      0.00         2
#           80       0.00      0.00      0.00         1
#           85       0.00      0.00      0.00         1
#           86       0.00      0.00      0.00         3
#           87       0.00      0.00      0.00         1
#           88       0.00      0.00      0.00         1
#           89       0.00      0.00      0.00         1
#           95       0.00      0.00      0.00         1
#           98       0.00      0.00      0.00         1
#
#     accuracy                           0.20      1983
#    macro avg       0.10      0.10      0.10      1983
# weighted avg       0.19      0.20      0.18      1983

# %%
i=0
diff = []
diff_tot = 0

for score in y_test:
    diff.append(predicted_values[i]-y_test[i])
    diff_tot = diff_tot + abs(predicted_values[i]-y_test[i])
    i=i+1
    
dtc_avg = diff_tot/len(y_test)
aec.append(dtc_avg)
    
print("Average error in score: ", diff_tot/len(y_test))
# Out:
# Average error in score:  1.622289460413515

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a histogram
plt.hist(diff, bins=30, density=True, color='pink', edgecolor='black', label='Data Distribution')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Prediction Error')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Use a GaussianNB machine learning algorithm

# https://iq.opengenus.org/gaussian-naive-bayes/

from sklearn.naive_bayes import GaussianNB

NaiveBayes = GaussianNB()

NaiveBayes.fit(X_train,y_train)

predicted_values = NaiveBayes.predict(X_test)
x = metrics.accuracy_score(y_test, predicted_values)
acc.append(x)
model.append('Naive Bayes')

print("Naive Bayes's Accuracy is: ", x)

print(classification_report(y_test,predicted_values))
# Out:
# Naive Bayes's Accuracy is:  0.046898638426626324
#               precision    recall  f1-score   support
#
#           57       0.00      0.00      0.00         0
#           58       0.00      0.00      0.00         5
#           59       0.14      0.08      0.10        13
#           60       0.33      0.08      0.13        25
#           61       0.33      0.07      0.11        59
#           62       0.17      0.03      0.04        78
#           63       0.22      0.09      0.13       109
#           64       0.23      0.03      0.05       161
#           65       0.15      0.04      0.06       192
#           66       0.30      0.10      0.15       227
#           67       0.19      0.07      0.11       202
#           68       0.10      0.01      0.02       232
#           69       0.22      0.05      0.08       195
#           70       0.25      0.03      0.06       149
#           71       0.25      0.02      0.03       128
#           72       1.00      0.01      0.02        98
#           73       0.00      0.00      0.00        49
#           74       0.00      0.00      0.00        27
#           75       0.04      0.25      0.08        16
#           76       0.00      0.00      0.00         4
#           77       0.00      0.00      0.00         2
#           78       0.00      0.00      0.00         2
#           79       0.00      0.00      0.00         0
#           80       0.01      1.00      0.01         1
#           82       0.00      0.00      0.00         0
#           84       0.00      0.00      0.00         0
#           85       0.00      0.00      0.00         1
#           86       0.00      0.00      0.00         3
#           87       0.00      0.00      0.00         1
#           88       0.00      0.00      0.00         1
#           89       0.00      0.00      0.00         1
#           92       0.00      0.00      0.00         0
#           93       0.00      0.00      0.00         0
#           94       0.00      0.00      0.00         0
#           95       0.00      0.00      0.00         1
#           97       0.00      0.00      0.00         0
#           98       0.00      0.00      0.00         1
#           99       0.00      0.00      0.00         0
#
#     accuracy                           0.05      1983
#    macro avg       0.10      0.05      0.03      1983
# weighted avg       0.24      0.05      0.07      1983

# %%
i=0
diff = []
diff_tot = 0

for score in y_test:
    diff.append(predicted_values[i]-y_test[i])
    diff_tot = diff_tot + abs(predicted_values[i]-y_test[i])
    i=i+1
    
nb_avg = diff_tot/len(y_test)
aec.append(nb_avg)
    
print("Average error in score: ", diff_tot/len(y_test))
# Out:
# Average error in score:  13.130105900151285

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a histogram
plt.hist(diff, bins=30, density=True, color='yellow', edgecolor='black', label='Data Distribution')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Prediction Error')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Use a Support Vector Machine machine algorithm

# https://towardsdatascience.com/support-vector-machine-introduction-to-machine-learning-algorithms-934a444fca47

from sklearn.svm import SVC

SVM = SVC(gamma='auto')

SVM.fit(X_train, y_train)

predicted_values = SVM.predict(X_test)

x = metrics.accuracy_score(y_test, predicted_values)
acc.append(x)
model.append('SVM')
print("SVM's Accuracy is: ", x)

print(classification_report(y_test, predicted_values))
# Out:
# SVM's Accuracy is:  0.21734745335350478
#               precision    recall  f1-score   support
#
#           58       0.00      0.00      0.00         5
#           59       0.00      0.00      0.00        13
#           60       0.00      0.00      0.00        25
#           61       0.27      0.15      0.20        59
#           62       0.21      0.21      0.21        78
#           63       0.28      0.24      0.26       109
#           64       0.24      0.18      0.21       161
#           65       0.20      0.29      0.24       192
#           66       0.19      0.23      0.21       227
#           67       0.21      0.28      0.24       202
#           68       0.20      0.23      0.22       232
#           69       0.22      0.22      0.22       195
#           70       0.20      0.32      0.25       149
#           71       0.22      0.16      0.18       128
#           72       0.27      0.17      0.21        98
#           73       0.00      0.00      0.00        49
#           74       0.38      0.19      0.25        27
#           75       0.67      0.12      0.21        16
#           76       0.00      0.00      0.00         4
#           77       0.00      0.00      0.00         2
#           78       0.00      0.00      0.00         2
#           80       0.00      0.00      0.00         1
#           85       0.00      0.00      0.00         1
#           86       0.00      0.00      0.00         3
#           87       0.00      0.00      0.00         1
#           88       0.00      0.00      0.00         1
#           89       0.00      0.00      0.00         1
#           95       0.00      0.00      0.00         1
#           98       0.00      0.00      0.00         1
#
#     accuracy                           0.22      1983
#    macro avg       0.13      0.10      0.11      1983
# weighted avg       0.21      0.22      0.21      1983

# %%
i=0
diff = []
diff_tot = 0

for score in y_test:
    diff.append(predicted_values[i]-y_test[i])
    diff_tot = diff_tot + abs(predicted_values[i]-y_test[i])
    i=i+1
    
svm_avg = diff_tot/len(y_test)
aec.append(svm_avg)
    
print("Average error in score: ", diff_tot/len(y_test))
# Out:
# Average error in score:  1.54059505799294

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a histogram
plt.hist(diff, bins=30, density=True, color='purple', edgecolor='black', label='Data Distribution')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Prediction Error')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Use a Logistic Regression machine learning algorithm

# https://www.statisticssolutions.com/free-resources/directory-of-statistical-analyses/what-is-logistic-regression/

from sklearn.linear_model import LogisticRegression

LogReg = LogisticRegression(random_state=2)

LogReg.fit(X_train, y_train)

predicted_values = LogReg.predict(X_test)

x = metrics.accuracy_score(y_test, predicted_values)
acc.append(x)
model.append('Logistic Regression')
print("Logistic Regression's Accuracy is: ", x)

print(classification_report(y_test, predicted_values))
# Out:
# Logistic Regression's Accuracy is:  0.13010590015128592
#               precision    recall  f1-score   support
#
#           58       0.00      0.00      0.00         5
#           59       0.00      0.00      0.00        13
#           60       0.00      0.00      0.00        25
#           61       0.03      0.02      0.02        59
#           62       0.16      0.09      0.11        78
#           63       0.00      0.00      0.00       109
#           64       0.15      0.02      0.03       161
#           65       0.13      0.23      0.17       192
#           66       0.13      0.20      0.16       227
#           67       0.11      0.14      0.12       202
#           68       0.13      0.22      0.17       232
#           69       0.15      0.23      0.18       195
#           70       0.14      0.20      0.17       149
#           71       0.00      0.00      0.00       128
#           72       0.00      0.00      0.00        98
#           73       0.07      0.02      0.03        49
#           74       0.00      0.00      0.00        27
#           75       0.00      0.00      0.00        16
#           76       0.00      0.00      0.00         4
#           77       0.00      0.00      0.00         2
#           78       0.00      0.00      0.00         2
#           80       0.00      0.00      0.00         1
#           85       0.00      0.00      0.00         1
#           86       0.00      0.00      0.00         3
#           87       0.00      0.00      0.00         1
#           88       0.00      0.00      0.00         1
#           89       0.00      0.00      0.00         1
#           95       0.00      0.00      0.00         1
#           98       0.00      0.00      0.00         1
#
#     accuracy                           0.13      1983
#    macro avg       0.04      0.05      0.04      1983
# weighted avg       0.10      0.13      0.11      1983

# %%
i=0
diff = []
diff_tot = 0

for score in y_test:
    diff.append(predicted_values[i]-y_test[i])
    diff_tot = diff_tot + abs(predicted_values[i]-y_test[i])
    i=i+1
    
lr_avg = diff_tot/len(y_test)
aec.append(lr_avg)
    
print("Average error in score: ", diff_tot/len(y_test))
# Out:
# Average error in score:  2.3479576399394855

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a histogram
plt.hist(diff, bins=30, density=True, color='orange', edgecolor='black', label='Data Distribution')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Prediction Error')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Use a RandomForestClassifier machine algorithm with looping n_estimators parameter

from sklearn.ensemble import RandomForestClassifier
import warnings

warnings.filterwarnings('ignore')

results = []
results2 = []
random_state = []

for i in range(2, 20):
    random_state.append(i)
    clf = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='auto', max_leaf_nodes=None,
            min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0,
            n_estimators=i, n_jobs=1, oob_score=False, random_state=None,
            verbose=0, warm_start=False)
    clf.fit(X_train, y_train)
    predicted_values = clf.predict(X_test)
    x = metrics.accuracy_score(y_test, predicted_values)
    results.append(x)
    
    i=0
    diff = []
    diff_tot = 0

    for score in y_test:
        diff.append(predicted_values[i]-score)
        diff_tot = diff_tot + abs(predicted_values[i]-score)
        i=i+1

    rfc_avg = diff_tot/len(y_predict)
    results2.append(rfc_avg)

import matplotlib.pyplot as plt 

plt.scatter(random_state, results2, s=10, c='r', alpha=0.5)
#plt.scatter(random_state, results, s=10, c='b', alpha=0.5)
print(results)
# Out:
# [0.16389309127584467, 0.13514876449823499, 0.13918305597579425, 0.16389309127584467, 0.1649016641452345, 0.18709026727181038, 0.2102874432677761, 0.2032274331820474, 0.21381744831064045, 0.20574886535552195, 0.2022188603126576, 0.19717599596570853, 0.2027231467473525, 0.19062027231467474, 0.21986888552697934, 0.2087745839636914, 0.2183560262228946, 0.20726172465960666]

# %%
#useful tutorial at: https://www.geeksforgeeks.org/random-forest-classifier-using-scikit-learn/

from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()

# %%
RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='auto', max_leaf_nodes=None,
            min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0,
            n_estimators=15, n_jobs=1, oob_score=False, random_state=None,
            verbose=0, warm_start=False)
# Out:
# RandomForestClassifier(max_features='auto', n_estimators=15, n_jobs=1)

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# make predictions
y_predict = clf.predict(X_test)

x = metrics.accuracy_score(y_test, predicted_values)
acc.append(x)
model.append('Random Forest')
print("Random Forest's Accuracy is: ", x)

print(classification_report(y_test, predicted_values))
# Out:
# Random Forest's Accuracy is:  0.21280887544125063
#               precision    recall  f1-score   support
#
#           58       0.00      0.00      0.00         5
#           59       0.17      0.08      0.11        13
#           60       0.21      0.16      0.18        25
#           61       0.24      0.19      0.21        59
#           62       0.24      0.23      0.23        78
#           63       0.21      0.26      0.23       109
#           64       0.25      0.25      0.25       161
#           65       0.23      0.28      0.25       192
#           66       0.20      0.21      0.20       227
#           67       0.20      0.26      0.23       202
#           68       0.18      0.19      0.18       232
#           69       0.21      0.23      0.22       195
#           70       0.20      0.22      0.21       149
#           71       0.27      0.20      0.23       128
#           72       0.22      0.13      0.17        98
#           73       0.11      0.02      0.03        49
#           74       0.20      0.11      0.14        27
#           75       0.50      0.06      0.11        16
#           76       0.00      0.00      0.00         4
#           77       0.00      0.00      0.00         2
#           78       0.00      0.00      0.00         2
#           80       0.00      0.00      0.00         1
#           85       0.00      0.00      0.00         1
#           86       0.00      0.00      0.00         3
#           87       0.00      0.00      0.00         1
#           88       0.00      0.00      0.00         1
#           89       0.00      0.00      0.00         1
#           95       0.00      0.00      0.00         1
#           98       0.00      0.00      0.00         1
#
#     accuracy                           0.21      1983
#    macro avg       0.13      0.11      0.11      1983
# weighted avg       0.21      0.21      0.21      1983

# %%
# show the inputs and predicted outputs and make an array of differences
i=0
diff = []
diff_tot = 0

for score in y_test:
    diff.append(y_predict[i]-score)
    #print("n=%s, Predicted=%s, Actual=%s" % (i, y_predict[i], score))
    diff_tot = diff_tot + abs(y_predict[i]-score)
    i=i+1
    
rfc_avg = diff_tot/len(y_predict)
aec.append(rfc_avg)

print("Average error in score: ", diff_tot/len(y_predict))
# Out:
# Average error in score:  1.3383761976802824

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a histogram
plt.hist(diff, bins=30, density=True, color='skyblue', edgecolor='black', label='Data Distribution')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Prediction Error')
plt.legend()
plt.grid(True)
plt.show()

# %%
#show an exact accuracy comparison

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=[10,5],dpi = 100)
plt.title('Accuracy Comparison Predicting Exact Score (longer is better)')
plt.xlabel('Accuracy')
plt.ylabel('Algorithm')
sns.barplot(x = acc,y = model,palette='dark')
# Out:
# <Axes: title={'center': 'Accuracy Comparison Predicting Exact Score (longer is better)'}, xlabel='Accuracy', ylabel='Algorithm'>

# %%
#show an amount of average error comparison

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=[10,5],dpi = 100)
plt.title('Accuracy Comparison Average Score Error (shorter is better)')
plt.xlabel('Accuracy')
plt.ylabel('Algorithm')
sns.barplot(x = aec,y = model,palette='dark')
# Out:
# <Axes: title={'center': 'Accuracy Comparison Average Score Error (shorter is better)'}, xlabel='Accuracy', ylabel='Algorithm'>

# %%
#Better to compare to a statistic like average error of predicted score points?

# %%
#Make a CLF prediction on a new case

import numpy as np

data = np.array([[10,78,1,2,1,8,74,2,1,1,0,2,0,1,4,0,2,0,0]])
prediction = clf.predict(data)
print(prediction)
# Out:
# [65]

# %%
#Make an SVM prediction on another new case

data = np.array([[10,82,0,1,1,8,79,2,1,1,0,2,0,1,4,0,2,0,0]])

prediction = SVM.predict(data)
print(prediction)
# Out:
# [65]
