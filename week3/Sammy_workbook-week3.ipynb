# %%
import pandas as pd
students=pd.read_csv("StudentPerformanceFactors.csv")
print(students)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                            No            7               73
# 1                            No            8               59
# 2                           Yes            7               91
# 3                           Yes            8               98
# 4                           Yes            6               65
# ...                         ...          ...              ...
# 6602                         No            7               76
# 6603                         No            8               81
# 6604                        Yes            6               65
# 6605                        Yes            6               91
# 6606                        Yes            9               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 0                 Low             Yes                  0           Low
# 1                 Low             Yes                  2        Medium
# 2              Medium             Yes                  2        Medium
# 3              Medium             Yes                  1        Medium
# 4              Medium             Yes                  3        Medium
# ...               ...             ...                ...           ...
# 6602           Medium             Yes                  1          High
# 6603           Medium             Yes                  3           Low
# 6604              Low             Yes                  3           Low
# 6605             High             Yes                  2           Low
# 6606           Medium             Yes                  0        Medium
#
#      Teacher_Quality School_Type Peer_Influence  Physical_Activity  \
# 0             Medium      Public       Positive                  3
# 1             Medium      Public       Negative                  4
# 2             Medium      Public        Neutral                  4
# 3             Medium      Public       Negative                  4
# 4               High      Public        Neutral                  4
# ...              ...         ...            ...                ...
# 6602          Medium      Public       Positive                  2
# 6603            High      Public       Positive                  2
# 6604          Medium      Public       Negative                  2
# 6605          Medium     Private       Positive                  3
# 6606          Medium      Public       Positive                  4
#
#      Learning_Disabilities Parental_Education_Level Distance_from_Home  Gender
# 0                       No              High School               Near    Male
# 1                       No                  College           Moderate  Female
# 2                       No             Postgraduate               Near    Male
# 3                       No              High School           Moderate    Male
# 4                       No                  College               Near  Female
# ...                    ...                      ...                ...     ...
# 6602                    No              High School               Near  Female
# 6603                    No              High School               Near  Female
# 6604                    No             Postgraduate               Near  Female
# 6605                    No              High School                Far  Female
# 6606                    No             Postgraduate               Near    Male
#
# [6607 rows x 19 columns]

# %%
print(students.Sleep_Hours)
# Out:
# 0       7
# 1       8
# 2       7
# 3       8
# 4       6
#        ..
# 6602    7
# 6603    8
# 6604    6
# 6605    6
# 6606    9
# Name: Sleep_Hours, Length: 6607, dtype: int64

# %%
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

plt.figure(figsize=(6,6))
plt.plot(students.Exam_Score)

# %%
#encode Parental_Involvement column to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_2 = students.Parental_Involvement
set_col_2 = list(set(col_2))
le.fit(col_2)
dict(zip(set_col_2, le.transform(set_col_2)))

students.Parental_Involvement = le.transform(students.Parental_Involvement)

print(students.Parental_Involvement)
# Out:
# 0       1
# 1       1
# 2       2
# 3       1
# 4       2
#        ..
# 6602    0
# 6603    0
# 6604    2
# 6605    0
# 6606    2
# Name: Parental_Involvement, Length: 6607, dtype: int64

# %%
#encode Access_to_Resources column to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_3 = students.Access_to_Resources
set_col_3 = list(set(col_3))
le.fit(col_3)
dict(zip(set_col_3, le.transform(set_col_3)))

students.Access_to_Resources = le.transform(students.Access_to_Resources)

print(students.Access_to_Resources)
# Out:
# 0       0
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 6602    2
# 6603    2
# 6604    1
# 6605    0
# 6606    1
# Name: Access_to_Resources, Length: 6607, dtype: int64

# %%
#encode Extracurricular_Activities column to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_4 = students.Extracurricular_Activities
set_col_4 = list(set(col_4))
le.fit(col_4)
dict(zip(set_col_4, le.transform(set_col_4)))

students.Extracurricular_Activities = le.transform(students.Extracurricular_Activities)

print(students.Extracurricular_Activities)
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       1
#        ..
# 6602    0
# 6603    0
# 6604    1
# 6605    1
# 6606    1
# Name: Extracurricular_Activities, Length: 6607, dtype: int64

# %%
#encode Motivation_Level column to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_7 = students.Motivation_Level
set_col_7 = list(set(col_7))
le.fit(col_7)
dict(zip(set_col_7, le.transform(set_col_7)))

students.Motivation_Level = le.transform(students.Motivation_Level)

print(students.Motivation_Level)
# Out:
# 0       1
# 1       1
# 2       2
# 3       2
# 4       2
#        ..
# 6602    2
# 6603    2
# 6604    1
# 6605    0
# 6606    2
# Name: Motivation_Level, Length: 6607, dtype: int64

# %%
#encode Internet_Access to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_8 = students.Internet_Access
set_col_8 = list(set(col_8))
le.fit(col_8)
dict(zip(set_col_8, le.transform(set_col_8)))

students.Internet_Access = le.transform(students.Internet_Access)

print(students.Internet_Access)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6602    1
# 6603    1
# 6604    1
# 6605    1
# 6606    1
# Name: Internet_Access, Length: 6607, dtype: int64

# %%
#encode Family_Income to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_10 = students.Family_Income
set_col_10 = list(set(col_10))
le.fit(col_10)
dict(zip(set_col_10, le.transform(set_col_10)))

students.Family_Income = le.transform(students.Family_Income)

print(students.Family_Income)
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 6602    0
# 6603    1
# 6604    1
# 6605    1
# 6606    2
# Name: Family_Income, Length: 6607, dtype: int64

# %%
#encode Teacher_Quality to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_11 = students.Teacher_Quality
set_col_11 = list(set(col_11))
le.fit(col_11)
dict(zip(set_col_11, le.transform(set_col_11)))

students.Teacher_Quality = le.transform(students.Teacher_Quality)

print(students.Teacher_Quality)
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       0
#        ..
# 6602    2
# 6603    0
# 6604    2
# 6605    2
# 6606    2
# Name: Teacher_Quality, Length: 6607, dtype: int64

# %%
#encode School_Type to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_12 = students.School_Type
set_col_12 = list(set(col_12))
le.fit(col_12)
dict(zip(set_col_12, le.transform(set_col_12)))

students.School_Type = le.transform(students.School_Type)

print(students.School_Type)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6602    1
# 6603    1
# 6604    1
# 6605    0
# 6606    1
# Name: School_Type, Length: 6607, dtype: int64

# %%
#encode Peer_Influence to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_13 = students.Peer_Influence
set_col_13 = list(set(col_13))
le.fit(col_13)
dict(zip(set_col_13, le.transform(set_col_13)))

students.Peer_Influence = le.transform(students.Peer_Influence)

print(students.Peer_Influence)
# Out:
# 0       2
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 6602    2
# 6603    2
# 6604    0
# 6605    2
# 6606    2
# Name: Peer_Influence, Length: 6607, dtype: int64

# %%
#encode Learning_Disabilities to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_15 = students.Learning_Disabilities
set_col_15 = list(set(col_15))
le.fit(col_15)
dict(zip(set_col_15, le.transform(set_col_15)))

students.Learning_Disabilities = le.transform(students.Learning_Disabilities)

print(students.Learning_Disabilities)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6602    0
# 6603    0
# 6604    0
# 6605    0
# 6606    0
# Name: Learning_Disabilities, Length: 6607, dtype: int64

# %%
#encode Parental_Education_Level to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_16 = students.Parental_Education_Level
set_col_16 = list(set(col_16))
le.fit(col_16)
dict(zip(set_col_16, le.transform(set_col_16)))

students.Parental_Education_Level = le.transform(students.Parental_Education_Level)

print(students.Parental_Education_Level)
# Out:
# 0       1
# 1       0
# 2       2
# 3       1
# 4       0
#        ..
# 6602    1
# 6603    1
# 6604    2
# 6605    1
# 6606    2
# Name: Parental_Education_Level, Length: 6607, dtype: int64

# %%
#encode Distance_from_Home to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_17 = students.Distance_from_Home
set_col_17 = list(set(col_17))
le.fit(col_17)
dict(zip(set_col_17, le.transform(set_col_17)))

students.Distance_from_Home = le.transform(students.Distance_from_Home)

print(students.Distance_from_Home)
# Out:
# 0       2
# 1       1
# 2       2
# 3       1
# 4       2
#        ..
# 6602    2
# 6603    2
# 6604    2
# 6605    0
# 6606    2
# Name: Distance_from_Home, Length: 6607, dtype: int64

# %%
#encode Gender to integer

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
col_18 = students.Gender
set_col_18 = list(set(col_18))
le.fit(col_18)
dict(zip(set_col_18, le.transform(set_col_18)))

students.Gender = le.transform(students.Gender)

print(students.Gender)
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 6602    0
# 6603    0
# 6604    0
# 6605    0
# 6606    1
# Name: Gender, Length: 6607, dtype: int64

# %%
exam_score=pd.read_csv("ExamScore.csv")
print(exam_score)
# Out:
#       Exam_Score
# 0             67
# 1             61
# 2             74
# 3             71
# 4             70
# ...          ...
# 6602          68
# 6603          69
# 6604          68
# 6605          68
# 6606          64
#
# [6607 rows x 1 columns]

# %%
#convert 2-D array to 1-D
scoreresult = []

for i in range(0, len(exam_score.Exam_Score)):
    scoreresult.append(exam_score.Exam_Score[i])
    
print(scoreresult)
# Out:
,
#  <matplotlib.lines.Line2D at 0x7fe04e69b340>,
#  <matplotlib.lines.Line2D at 0x7fe04e69b430>,
#  <matplotlib.lines.Line2D at 0x7fe04e69b520>,
#  <matplotlib.lines.Line2D at 0x7fe04e69b610>,
#  <matplotlib.lines.Line2D at 0x7fe04e661ed0>,
#  <matplotlib.lines.Line2D at 0x7fe04e661e40>,
#  <matplotlib.lines.Line2D at 0x7fe04e69b7c0>,
#  <matplotlib.lines.Line2D at 0x7fe04e69b8b0>,
#  <matplotlib.lines.Line2D at 0x7fe04e69b9a0>,
#  <matplotlib.lines.Line2D at 0x7fe04e69ba90>,
#  <matplotlib.lines.Line2D at 0x7fe04e69bb50>,
#  <matplotlib.lines.Line2D at 0x7fe04e69bc40>,
#  <matplotlib.lines.Line2D at 0x7fe04e69bd30>,
#  <matplotlib.lines.Line2D at 0x7fe04e69be20>,
#  <matplotlib.lines.Line2D at 0x7fe04e69bf10>,
#  <matplotlib.lines.Line2D at 0x7fe04e6a0040>,
#  <matplotlib.lines.Line2D at 0x7fe04e6a0130>]

# %%
#Use a DecisionTreeClassifier machine algorithm

# https://medium.com/swlh/decision-tree-classification-de64fc4d5aac

from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn import tree

from sklearn.tree import DecisionTreeClassifier

DecisionTree = DecisionTreeClassifier(criterion="entropy",random_state=2,max_depth=5)

DecisionTree.fit(X_train, y_train)

predicted_values = DecisionTree.predict(X_test)
x = metrics.accuracy_score(y_test, predicted_values)
acc.append(x)
model.append('Decision Tree')
print("DecisionTrees's Accuracy is: ", x*100)

print(classification_report(y_test, predicted_values))
# Out:
# DecisionTrees's Accuracy is:  20.776601109430157
#               precision    recall  f1-score   support
#
#           56       0.00      0.00      0.00         1
#           57       0.00      0.00      0.00         1
#           58       0.00      0.00      0.00         6
#           59       0.00      0.00      0.00        16
#           60       0.00      0.00      0.00        25
#           61       0.22      0.46      0.30        57
#           62       0.00      0.00      0.00        74
#           63       0.19      0.08      0.11       100
#           64       0.21      0.29      0.25       148
#           65       0.22      0.39      0.28       209
#           66       0.18      0.27      0.21       196
#           67       0.18      0.11      0.13       228
#           68       0.37      0.12      0.18       276
#           69       0.20      0.39      0.26       176
#           70       0.18      0.24      0.21       164
#           71       0.18      0.10      0.13       110
#           72       0.22      0.17      0.19        89
#           73       0.00      0.00      0.00        39
#           74       0.21      0.24      0.22        38
#           75       0.22      0.25      0.24         8
#           76       0.00      0.00      0.00         6
#           78       0.00      0.00      0.00         1
#           79       0.00      0.00      0.00         1
#           80       0.00      0.00      0.00         2
#           82       0.00      0.00      0.00         1
#           86       0.00      0.00      0.00         2
#           87       0.00      0.00      0.00         1
#           88       0.00      0.00      0.00         1
#           89       0.00      0.00      0.00         1
#           93       0.00      0.00      0.00         1
#           94       0.00      0.00      0.00         1
#           95       0.00      0.00      0.00         1
#           97       0.00      0.00      0.00         2
#           98       0.00      0.00      0.00         1
#
#     accuracy                           0.21      1983
#    macro avg       0.08      0.09      0.08      1983
# weighted avg       0.20      0.21      0.19      1983

# %%
#Use a GaussianNB machine learning algorithm

# https://iq.opengenus.org/gaussian-naive-bayes/

from sklearn.naive_bayes import GaussianNB

NaiveBayes = GaussianNB()

NaiveBayes.fit(X_train,y_train)

predicted_values = NaiveBayes.predict(X_test)
x = metrics.accuracy_score(y_test, predicted_values)
acc.append(x)
model.append('Naive Bayes')
print("Naive Bayes's Accuracy is: ", x)

print(classification_report(y_test,predicted_values))
# Out:
# Naive Bayes's Accuracy is:  0.11699445284921836
#               precision    recall  f1-score   support
#
#           56       0.00      0.00      0.00         1
#           57       0.11      1.00      0.20         1
#           58       0.00      0.00      0.00         6
#           59       0.09      0.06      0.07        16
#           60       0.29      0.08      0.12        25
#           61       0.24      0.12      0.16        57
#           62       0.20      0.07      0.10        74
#           63       0.26      0.13      0.17       100
#           64       0.21      0.09      0.12       148
#           65       0.27      0.17      0.21       209
#           66       0.18      0.13      0.15       196
#           67       0.19      0.12      0.15       228
#           68       0.35      0.14      0.20       276
#           69       0.20      0.12      0.15       176
#           70       0.29      0.14      0.19       164
#           71       0.09      0.03      0.04       110
#           72       0.41      0.08      0.13        89
#           73       0.33      0.03      0.05        39
#           74       0.00      0.00      0.00        38
#           75       0.00      0.00      0.00         8
#           76       0.13      0.67      0.22         6
#           77       0.00      0.00      0.00         0
#           78       0.00      0.00      0.00         1
#           79       0.00      0.00      0.00         1
#           80       0.01      0.50      0.02         2
#           82       0.00      0.00      0.00         1
#           84       0.00      0.00      0.00         0
#           86       0.00      0.00      0.00         2
#           87       0.00      0.00      0.00         1
#           88       0.00      0.00      0.00         1
#           89       0.00      0.00      0.00         1
#           92       0.00      0.00      0.00         0
#           93       0.00      0.00      0.00         1
#           94       0.00      0.00      0.00         1
#           95       0.00      0.00      0.00         1
#           97       0.00      0.00      0.00         2
#           98       0.00      0.00      0.00         1
#           99       0.00      0.00      0.00         0
#
#     accuracy                           0.12      1983
#    macro avg       0.10      0.10      0.07      1983
# weighted avg       0.24      0.12      0.15      1983

# %%
#Use a Support Vector Machine machine algorithm

# https://towardsdatascience.com/support-vector-machine-introduction-to-machine-learning-algorithms-934a444fca47

from sklearn.svm import SVC

SVM = SVC(gamma='auto')

SVM.fit(X_train, y_train)

predicted_values = SVM.predict(X_test)

x = metrics.accuracy_score(y_test, predicted_values)
acc.append(x)
model.append('SVM')
print("SVM's Accuracy is: ", x)

print(classification_report(y_test, predicted_values))
# Out:
# SVM's Accuracy is:  0.2254160363086233
#               precision    recall  f1-score   support
#
#           56       0.00      0.00      0.00         1
#           57       0.00      0.00      0.00         1
#           58       0.00      0.00      0.00         6
#           59       0.00      0.00      0.00        16
#           60       0.00      0.00      0.00        25
#           61       0.34      0.19      0.25        57
#           62       0.27      0.22      0.24        74
#           63       0.21      0.19      0.20       100
#           64       0.22      0.19      0.20       148
#           65       0.25      0.28      0.26       209
#           66       0.17      0.34      0.23       196
#           67       0.26      0.24      0.25       228
#           68       0.27      0.23      0.25       276
#           69       0.21      0.30      0.25       176
#           70       0.20      0.23      0.21       164
#           71       0.20      0.17      0.19       110
#           72       0.24      0.20      0.22        89
#           73       0.22      0.05      0.08        39
#           74       0.12      0.03      0.04        38
#           75       1.00      0.12      0.22         8
#           76       0.00      0.00      0.00         6
#           78       0.00      0.00      0.00         1
#           79       0.00      0.00      0.00         1
#           80       0.00      0.00      0.00         2
#           82       0.00      0.00      0.00         1
#           86       0.00      0.00      0.00         2
#           87       0.00      0.00      0.00         1
#           88       0.00      0.00      0.00         1
#           89       0.00      0.00      0.00         1
#           93       0.00      0.00      0.00         1
#           94       0.00      0.00      0.00         1
#           95       0.00      0.00      0.00         1
#           97       0.00      0.00      0.00         2
#           98       0.00      0.00      0.00         1
#
#     accuracy                           0.23      1983
#    macro avg       0.12      0.09      0.09      1983
# weighted avg       0.23      0.23      0.22      1983

# %%
#Use a Logistic Regression machine learning algorithm

# https://www.statisticssolutions.com/free-resources/directory-of-statistical-analyses/what-is-logistic-regression/

from sklearn.linear_model import LogisticRegression

LogReg = LogisticRegression(random_state=2)

LogReg.fit(X_train, y_train)

predicted_values = LogReg.predict(X_test)

x = metrics.accuracy_score(y_test, predicted_values)
acc.append(x)
model.append('Logistic Regression')
print("Logistic Regression's Accuracy is: ", x)

print(classification_report(y_test, predicted_values))
# Out:
# Logistic Regression's Accuracy is:  0.13262733232476046
#               precision    recall  f1-score   support
#
#           56       0.00      0.00      0.00         1
#           57       0.00      0.00      0.00         1
#           58       0.00      0.00      0.00         6
#           59       0.00      0.00      0.00        16
#           60       0.00      0.00      0.00        25
#           61       0.17      0.07      0.10        57
#           62       0.00      0.00      0.00        74
#           63       0.08      0.01      0.02       100
#           64       0.25      0.01      0.01       148
#           65       0.15      0.14      0.14       209
#           66       0.14      0.55      0.22       196
#           67       0.12      0.10      0.11       228
#           68       0.18      0.11      0.14       276
#           69       0.14      0.20      0.16       176
#           70       0.10      0.20      0.13       164
#           71       0.00      0.00      0.00       110
#           72       0.00      0.00      0.00        89
#           73       0.00      0.00      0.00        39
#           74       0.00      0.00      0.00        38
#           75       0.00      0.00      0.00         8
#           76       0.00      0.00      0.00         6
#           78       0.00      0.00      0.00         1
#           79       0.00      0.00      0.00         1
#           80       0.00      0.00      0.00         2
#           82       0.00      0.00      0.00         1
#           86       0.00      0.00      0.00         2
#           87       0.00      0.00      0.00         1
#           88       0.00      0.00      0.00         1
#           89       0.00      0.00      0.00         1
#           93       0.00      0.00      0.00         1
#           94       0.00      0.00      0.00         1
#           95       0.00      0.00      0.00         1
#           97       0.00      0.00      0.00         2
#           98       0.00      0.00      0.00         1
#
#     accuracy                           0.13      1983
#    macro avg       0.04      0.04      0.03      1983
# weighted avg       0.12      0.13      0.10      1983

# %%
i=0
diff = []
diff_tot = 0

for score in y_test:
    diff.append(predicted_values[i]-y_test[i])
    diff_tot = diff_tot + abs(predicted_values[i]-y_test[i])
    i=i+1
    
print("Average error in score: ", diff_tot/len(y_test))
# Out:
# Average error in score:  1.5648008068582955

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a histogram
plt.hist(diff, bins=30, density=True, color='orange', edgecolor='black', label='Data Distribution')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Prediction Error')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Use a RandomForestClassifier machine algorithm with looping n_estimators parameter

from sklearn.ensemble import RandomForestClassifier
import warnings

warnings.filterwarnings('ignore')

results = []
random_state = []

for i in range(2, 20):
    random_state.append(i)
    clf = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='auto', max_leaf_nodes=None,
            min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0,
            n_estimators=i, n_jobs=1, oob_score=False, random_state=None,
            verbose=0, warm_start=False)
    clf.fit(X_train, y_train)
    predicted_values = clf.predict(X_test)
    x = metrics.accuracy_score(y_test, predicted_values)
    results.append(x)

import matplotlib.pyplot as plt 

plt.scatter(random_state, results, s=10, c='b', alpha=0.5)
print(results)
# Out:
# [0.16036308623298035, 0.13212304589006554, 0.16742309631870902, 0.1669188098840141, 0.1805345436207766, 0.19465456379223398, 0.19768028240040342, 0.19213313161875945, 0.19162884518406456, 0.2037317196167423, 0.20726172465960666, 0.2087745839636914, 0.21331316187594554, 0.18557740796772568, 0.21230458900655572, 0.2168431669188099, 0.20978315683308119, 0.21331316187594554]

# %%
#useful tutorial at: https://www.geeksforgeeks.org/random-forest-classifier-using-scikit-learn/

from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()

# %%
RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='auto', max_leaf_nodes=None,
            min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0,
            n_estimators=15, n_jobs=1, oob_score=False, random_state=None,
            verbose=0, warm_start=False)
# Out:
# RandomForestClassifier(max_features='auto', n_estimators=15, n_jobs=1)

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# make predictions
y_predict = clf.predict(X_test)

x = metrics.accuracy_score(y_test, predicted_values)
acc.append(x)
model.append('Random Forest')
print("Random Forest's Accuracy is: ", x)

print(classification_report(y_test, predicted_values))
# Out:
# Random Forest's Accuracy is:  0.21331316187594554
#               precision    recall  f1-score   support
#
#           56       0.00      0.00      0.00         1
#           57       0.00      0.00      0.00         1
#           58       0.00      0.00      0.00         6
#           59       0.00      0.00      0.00        16
#           60       0.13      0.08      0.10        25
#           61       0.25      0.26      0.26        57
#           62       0.15      0.14      0.14        74
#           63       0.22      0.26      0.24       100
#           64       0.18      0.20      0.19       148
#           65       0.22      0.24      0.23       209
#           66       0.20      0.30      0.24       196
#           67       0.23      0.25      0.24       228
#           68       0.24      0.17      0.20       276
#           69       0.23      0.27      0.25       176
#           70       0.25      0.26      0.25       164
#           71       0.19      0.18      0.18       110
#           72       0.15      0.13      0.14        89
#           73       0.18      0.05      0.08        39
#           74       0.21      0.08      0.12        38
#           75       0.00      0.00      0.00         8
#           76       0.00      0.00      0.00         6
#           78       0.00      0.00      0.00         1
#           79       0.00      0.00      0.00         1
#           80       0.00      0.00      0.00         2
#           82       0.00      0.00      0.00         1
#           86       0.00      0.00      0.00         2
#           87       0.00      0.00      0.00         1
#           88       0.00      0.00      0.00         1
#           89       0.00      0.00      0.00         1
#           93       0.00      0.00      0.00         1
#           94       0.00      0.00      0.00         1
#           95       0.00      0.00      0.00         1
#           97       0.00      0.00      0.00         2
#           98       0.00      0.00      0.00         1
#
#     accuracy                           0.21      1983
#    macro avg       0.09      0.08      0.08      1983
# weighted avg       0.21      0.21      0.21      1983

# %%
# show the inputs and predicted outputs and make an array of differences
i=0
diff = []
diff_tot = 0

for score in y_test:
    diff.append(y_predict[i]-score)
    #print("n=%s, Predicted=%s, Actual=%s" % (i, y_predict[i], score))
    diff_tot = diff_tot + abs(y_predict[i]-score)
    i=i+1

print("Average error in score: ", diff_tot/len(y_predict))
# Out:
# 2760
# Average error in score:  1.3918305597579426

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a histogram
plt.hist(diff, bins=30, density=True, color='skyblue', edgecolor='black', label='Data Distribution')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Prediction Error')
plt.legend()
plt.grid(True)
plt.show()

# %%
#show an accuracy comparison

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=[10,5],dpi = 100)
plt.title('Accuracy Comparison Predicting Exact Score')
plt.xlabel('Accuracy')
plt.ylabel('Algorithm')
sns.barplot(x = acc,y = model,palette='dark')
# Out:
# <Axes: title={'center': 'Accuracy Comparison Predicting Exact Score'}, xlabel='Accuracy', ylabel='Algorithm'>

# %%
#Better to compare to a statistic like average error of predicted score points?

# %%
#Make a prediction on a new case

import numpy as np

data = np.array([[10,78,1,2,1,8,74,2,1,1,0,2,0,1,4,0,2,0,0]])
prediction = clf.predict(data)
print(prediction)
# Out:
# [62]

# %%
#Make a prediction on another case

data = np.array([[10,82,0,1,1,8,79,2,1,1,0,2,0,1,4,0,2,0,0]])

prediction = SVM.predict(data)
print(prediction)
# Out:
# [65]
